# %%
# %%
import os
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.env_util import make_vec_env
os.environ["PYGLET_HEADLESS"] = "true"
os.environ["PYGLET_HEADLESS_DEVICE"] = "0"

# %%
from envs.game_creator import get_game
from envs.miniworld.params import GameParams

# %%
game = get_game(name="miniworld_simp_lidar", params=GameParams(
    map_fpath="../experiments/maps/map_21.txt",
    # map_fpath=None,
    ltl_task=("until", "True", "f"),
    # ltl_task=("until", "True", ("and", "a", ("until", "True", "b"))),
    prob=1
), max_episode_steps=1500, do_transpose=False)

# %%
# %%
# model = PPO("CnnPolicy", game, 
#             verbose=1)
model = PPO("MlpPolicy", game, 
            verbose=1)
model.learn(total_timesteps=1000000)
model.save("ppo_cartpole")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.5e+03  |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 1158     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.5e+03     |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1028        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012651751 |
# |    clip_fraction        | 0.121       |
# ...

# %%
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.env_util import make_vec_env


# %%
# model = PPO("CnnPolicy", game, 
#             verbose=1)
model2 = PPO("MlpPolicy", game, 
            verbose=1)
model2.learn(total_timesteps=1000000)
model2.save("ppo_cartpole")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.5e+03  |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 1164     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.5e+03     |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1013        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012271872 |
# |    clip_fraction        | 0.125       |
# ...

# %%
import miniworld
import gymnasium as gym
env = gym.make('MiniWorld-FourRooms-v0')

# %%
model = PPO("CnnPolicy", env, 
            verbose=1)
# model2 = PPO("MlpPolicy", game, 
#             verbose=1)
model.learn(total_timesteps=1000000)
model.save("ppo_cartpole")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 250      |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 938      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 237       |
# |    ep_rew_mean          | 0.0576    |
# | time/                   |           |
# |    fps                  | 796       |
# |    iterations           | 2         |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0049002 |
# ...
